# %% [markdown]
# <a href="https://colab.research.google.com/github/suntwister/analytics-lab/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# creating dataframe
data = {
    'order_id': [1001, 1002, 1003, 1004, 1005],
    'customer_type': ['Regular', 'VIP', 'Regular', 'VIP', 'Guest'],
    'amount': [42000, 88000, 15000, 67000, 21000],
    'order_date': pd.to_datetime(['2024-03-05', '2024-03-12', '2024-02-28', '2024-03-08', '2024-03-01'])
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    order_id customer_type  amount order_date
# 0      1001       Regular   42000 2024-03-05
# 1      1002           VIP   88000 2024-03-12
# 2      1003       Regular   15000 2024-02-28
# 3      1004           VIP   67000 2024-03-08
# 4      1005         Guest   21000 2024-03-01

# %%
#Filter orders above ₦50,000
high_amount = df[df['amount'] > 50000]

# %%
#orders placed by VIPs
vip_orders = df[df['customer_type']== 'VIP']

# %%
#orders from March 2024 only
march_orders = df[df['order_date'].dt.month == 3]

# %%
march_orders
# Out:
#    order_id customer_type  amount order_date
# 0      1001       Regular   42000 2024-03-05
# 1      1002           VIP   88000 2024-03-12
# 3      1004           VIP   67000 2024-03-08
# 4      1005         Guest   21000 2024-03-01
